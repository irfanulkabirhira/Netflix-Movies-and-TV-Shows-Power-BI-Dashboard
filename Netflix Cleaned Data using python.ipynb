# %% [markdown]
# # Data Importing

# %%
import pandas as pd 
data = pd.read_csv("netflix_titles.csv")
data.head(1)
# Out:
#   show_id   type                 title  ... duration      listed_in                                        description
# 0      s1  Movie  Dick Johnson Is Dead  ...   90 min  Documentaries  As her father nears the end of his life, filmm...
#
# [1 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Null value

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.heatmap(data.isnull())
plt.show()

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
data.shape
# Out:
# (5332, 12)

# %% [markdown]
# # Date --> Column

# %%
data['date_added']
# Out:
# 7       September 24, 2021
# 8       September 24, 2021
# 9       September 24, 2021
# 12      September 23, 2021
# 24      September 21, 2021
#                ...
# 8801         March 9, 2016
# 8802     November 20, 2019
# 8804      November 1, 2019
# 8805      January 11, 2020
# 8806         March 2, 2019
# Name: date_added, Length: 5332, dtype: object

# %% [raw]
# Short Note--->
#
# text = "  August 4, 2017  "
# clean_text = text.strip()
# print(clean_text)  # Output: "August 4, 2017"
#
#
# Short Note -->
#
# pd.to_datetime("Hello", errors='coerce')  # Output: NaT
# pd.to_datetime("August 4, 2017", errors='coerce')  # Output: 2017-08-04

# %%
pd.to_datetime(data['date_added'].str.strip() , errors='coerce')
# Out:
# 7      2021-09-24
# 8      2021-09-24
# 9      2021-09-24
# 12     2021-09-23
# 24     2021-09-21
#           ...
# 8801   2016-03-09
# 8802   2019-11-20
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 5332, dtype: datetime64[ns]

# %%
data['date_added']=pd.to_datetime(data['date_added'].str.strip() , errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 7 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   datetime64[ns]
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 541.5+ KB

# %% [markdown]
# # Import ther Cleanded Dataset

# %%
data.to_csv(r"C:\Users\hirak\Downloads\powerBI projects\Netflix Movies and TV Shows\Netflix_cleaed_data.csv")
